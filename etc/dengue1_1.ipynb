# %%
# Importar bibliotecas necesarias
import pandas as pd

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt


# Load the CSV file into a DataFrame
df = pd.read_csv('dengue_abierto.csv')

# Display the first few rows of the DataFrame to understand its structure
df.head()
# Out:
#   FECHA_ACTUALIZACION  ID_REGISTRO  SEXO  EDAD_ANOS  ENTIDAD_RES  \
# 0          2024-02-19      1304867     1         11           30
# 1          2024-02-19      1304870     2         12           25
# 2          2024-02-19      1304893     1         24           23
# 3          2024-02-19      1304896     2         38           30
# 4          2024-02-19      1304928     2          4           31
#
#    MUNICIPIO_RES  HABLA_LENGUA_INDIG  INDIGENA  ENTIDAD_UM_NOTIF  \
# 0             48                   2         2                30
# 1             12                   2         2                25
# 2              4                   2         2                23
# 3            206                   2         2                30
# 4             90                   2         1                31
#
#    MUNICIPIO_UM_NOTIF  ...  INMUNOSUPR CIRROSIS_HEPATICA  EMBARAZO  DEFUNCION  \
# 0                  48  ...           2                 2         2          2
# ...

# %%
# 1. Cargar el conjunto de datos en un Pandas DataFrame
df = pd.read_csv('dengue_abierto.csv')

# %%
# 2. Revisar las primeras filas del DataFrame
df.head()
# Out:
#   FECHA_ACTUALIZACION  ID_REGISTRO  SEXO  EDAD_ANOS  ENTIDAD_RES  \
# 0          2024-02-19      1304867     1         11           30
# 1          2024-02-19      1304870     2         12           25
# 2          2024-02-19      1304893     1         24           23
# 3          2024-02-19      1304896     2         38           30
# 4          2024-02-19      1304928     2          4           31
#
#    MUNICIPIO_RES  HABLA_LENGUA_INDIG  INDIGENA  ENTIDAD_UM_NOTIF  \
# 0             48                   2         2                30
# 1             12                   2         2                25
# 2              4                   2         2                23
# 3            206                   2         2                30
# 4             90                   2         1                31
#
#    MUNICIPIO_UM_NOTIF  ...  INMUNOSUPR CIRROSIS_HEPATICA  EMBARAZO  DEFUNCION  \
# 0                  48  ...           2                 2         2          2
# ...

# %%
# 3. Verificar y manejar los datos faltantes si es necesario
df.isnull().sum()
# Manejar los datos faltantes según sea necesario, por ejemplo, utilizando df.dropna() o df.fillna().
# Out:
# FECHA_ACTUALIZACION       0
# ID_REGISTRO               0
# SEXO                      0
# EDAD_ANOS                 0
# ENTIDAD_RES               0
# MUNICIPIO_RES             0
# HABLA_LENGUA_INDIG        0
# INDIGENA                  0
# ENTIDAD_UM_NOTIF          0
# MUNICIPIO_UM_NOTIF        0
# INSTITUCION_UM_NOTIF      0
# FECHA_SIGN_SINTOMAS       0
# TIPO_PACIENTE             0
# HEMORRAGICOS              0
# DIABETES                  0
# HIPERTENSION              0
# ENFERMEDAD_ULC_PEPTICA    0
# ENFERMEDAD_RENAL          0
# INMUNOSUPR                0
# CIRROSIS_HEPATICA         0
# EMBARAZO                  0
# DEFUNCION                 0
# DICTAMEN                  1
# TOMA_MUESTRA              0
# RESULTADO_PCR             0
# ESTATUS_CASO              0
# ENTIDAD_ASIG              0
# MUNICIPIO_ASIG            0
# dtype: int64

# %%
# 4. Obtener información estadística básica sobre variables numéricas
df.describe()
# Out:
#         ID_REGISTRO          SEXO    EDAD_ANOS   ENTIDAD_RES  MUNICIPIO_RES  \
# count  2.656100e+04  26561.000000  26561.00000  26561.000000   26561.000000
# mean   1.315828e+06      1.474380     26.36275     17.076691      31.168518
# std    8.243057e+03      0.499353     17.31796      8.058724      62.437649
# min    1.299508e+06      1.000000      0.00000      1.000000       1.000000
# 25%    1.308845e+06      1.000000     12.00000     12.000000       2.000000
# 50%    1.315957e+06      1.000000     23.00000     14.000000       7.000000
# 75%    1.322932e+06      2.000000     38.00000     23.000000      38.000000
# max    1.329959e+06      2.000000    110.00000     35.000000     570.000000
#
#        HABLA_LENGUA_INDIG      INDIGENA  ENTIDAD_UM_NOTIF  MUNICIPIO_UM_NOTIF  \
# count        26561.000000  26561.000000      26561.000000        26561.000000
# mean             1.989910      1.987689         17.075713           33.040209
# ...

# %%
# 5. Identificar las variables categóricas en el conjunto de datos
categoricas = df.select_dtypes(include=['object']).columns
print(categoricas)
# Out:
# Index(['FECHA_ACTUALIZACION', 'FECHA_SIGN_SINTOMAS'], dtype='object')

# %%
# 6. Obtener las medidas de tendencia central para variables numéricas
columnas_numericas = df.select_dtypes(include=['int64', 'float64']).columns

media = df[columnas_numericas].mean()
moda = df[columnas_numericas].mode().iloc[0]
desviacion_estandar = df[columnas_numericas].std()

print("Media:\n", media)
print("\nModa:\n", moda)
print("\nDesviación Estándar:\n", desviacion_estandar)
# Out:
# Media:
#  ID_REGISTRO               1.315828e+06
# SEXO                      1.474380e+00
# EDAD_ANOS                 2.636275e+01
# ENTIDAD_RES               1.707669e+01
# MUNICIPIO_RES             3.116852e+01
# HABLA_LENGUA_INDIG        1.989910e+00
# INDIGENA                  1.987689e+00
# ENTIDAD_UM_NOTIF          1.707571e+01
# MUNICIPIO_UM_NOTIF        3.304021e+01
# INSTITUCION_UM_NOTIF      7.409096e+00
# TIPO_PACIENTE             1.207033e+00
# HEMORRAGICOS              1.992094e+00
# DIABETES                  1.978992e+00
# HIPERTENSION              1.986597e+00
# ENFERMEDAD_ULC_PEPTICA    1.999511e+00
# ENFERMEDAD_RENAL          1.997515e+00
# INMUNOSUPR                1.998343e+00
# CIRROSIS_HEPATICA         1.999322e+00
# EMBARAZO                  1.987237e+00
# DEFUNCION                 1.997101e+00
# DICTAMEN                  4.996875e+00
# TOMA_MUESTRA              1.501412e+00
# RESULTADO_PCR             4.823990e+00
# ESTATUS_CASO              1.564098e+00
# ...

# %%
# 7. Contar el número de casos por categoría para cada variable categórica
for columna in categoricas:
    print(f"\nNúmero de casos por categoría en {columna}:\n", df[columna].value_counts())
# Out:
# Número de casos por categoría en FECHA_ACTUALIZACION:
#  FECHA_ACTUALIZACION
# 2024-02-19    26561
# Name: count, dtype: int64
#
# Número de casos por categoría en FECHA_SIGN_SINTOMAS:
#  FECHA_SIGN_SINTOMAS
# 2024-01-15    835
# 2024-01-21    775
# 2024-01-22    769
# 2024-01-20    760
# 2024-01-08    750
# 2024-01-14    735
# 2024-01-29    707
# 2024-01-28    691
# 2024-01-16    685
# 2024-01-01    669
# 2024-01-07    660
# 2024-01-19    660
# 2024-01-12    648
# 2024-01-06    646
# 2024-01-23    641
# 2024-01-13    639
# 2024-01-09    631
# 2024-01-10    623
# 2024-01-18    615
# 2024-01-05    604
# 2024-01-11    598
# 2024-01-26    589
# 2024-01-30    585
# 2024-01-24    578
# 2024-01-27    577
# 2024-01-02    565
# 2024-01-17    561
# 2024-01-03    558
# 2024-02-10    558
# 2024-01-25    552
# 2024-02-06    551
# 2024-01-04    548
# 2024-02-05    546
# 2024-02-07    503
# 2024-02-12    494
# 2024-02-04    476
# 2024-01-31    474
# 2024-02-03    474
# 2024-02-11    466
# ...

# %%
# Obtain the number of cases of classic dengue and dengue hemorrhagic fever
classic_dengue_cases = df[df['Dengue_Type'] == 'Classic']['Number_of_Cases'].sum()
hemorrhagic_fever_cases = df[df['Dengue_Type'] == 'Hemorrhagic']['Number_of_Cases'].sum()

classic_dengue_cases, hemorrhagic_fever_cases
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\luisf\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File index.pyx:153, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:182, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Dengue_Type'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 2
# ...

# %%
# 9. Obtener el número de pacientes fallecidos por tipo de dengue y categoría de edad
fallecidos_por_tipo_edad = df.groupby(['tipo_dengue', 'edad_cat'])['fallecido'].sum()
print("\nNúmero de pacientes fallecidos por tipo de dengue y categoría de edad:\n", fallecidos_por_tipo_edad)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # 9. Obtener el número de pacientes fallecidos por tipo de dengue y categoría de edad
# ----> 2 fallecidos_por_tipo_edad = df.groupby(['tipo_dengue', 'edad_cat'])['fallecido'].sum()
#       3 print("\nNúmero de pacientes fallecidos por tipo de dengue y categoría de edad:\n", fallecidos_por_tipo_edad)
#
# NameError: name 'df' is not defined

# %%
# 10. Visualizar la distribución de casos de dengue por categoría utilizando gráficos de barras
plt.figure(figsize=(10, 6))
sns.countplot(x='categoria', data=df)
plt.title('Distribución de casos de Dengue por Categoría')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # 10. Visualizar la distribución de casos de dengue por categoría utilizando gráficos de barras
# ----> 2 plt.figure(figsize=(10, 6))
#       3 sns.countplot(x='categoria', data=df)
#       4 plt.title('Distribución de casos de Dengue por Categoría')
#
# NameError: name 'plt' is not defined
